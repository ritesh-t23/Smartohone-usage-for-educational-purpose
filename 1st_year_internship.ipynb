# %%
import pandas as pd
df=pd.read_csv('/content/SMARTPHONE.csv')
df.head()
# Out:
#           Timestamp what is your name? whether you are a  \
# 0  06-10-2023 11:28              Saran   college student
# 1  06-10-2023 11:28              Rahul   college student
# 2  06-10-2023 11:32       Mahimithran    college student
# 3  06-10-2023 11:35  Danish Ahmed N F    college student
# 4  06-10-2023 11:42             Vishnu   college student
#
#   1. How often do you use your smartphone for educational purposes?  \
# 0                            b) Several times a week
# 1                                           a) Daily
# 2                                           a) Daily
# 3                            b) Several times a week
# 4                                           a) Daily
#
#   2. Which of the following educational activities do you use your smartphone for?  \
# 0  a) Researching information for assignments/pro...
# 1  a) Researching information for assignments/pro...
# 2  a) Researching information for assignments/pro...
# ...

# %%
df.shape
# Out:
# (230, 18)

# %%
df['1. How often do you use your smartphone for educational purposes?'].value_counts()
# Out:
# 1. How often do you use your smartphone for educational purposes?
# a) Daily                   101
# b) Several times a week     94
# c) Once a week              20
# d) Rarely or never          14
# Name: count, dtype: int64

# %%
# %matplotlib inline
df['1. How often do you use your smartphone for educational purposes?'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='1. How often do you use your smartphone for educational purposes?'>

# %%
df['2. Which of the following educational activities do you use your smartphone for?'].value_counts()
# Out:
# 2. Which of the following educational activities do you use your smartphone for?
# a) Researching information for assignments/projects    101
# b) Reading e-books or digital textbooks                 57
# c) Taking online courses or attending webinars          34
# e) Educational games or quizzes                         15
# d) Language learning apps                               12
# f) None of the above                                    11
# Name: count, dtype: int64

# %%
df['2. Which of the following educational activities do you use your smartphone for?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['3. How helpful do you find educational apps on your smartphone?'].value_counts()
# Out:
# 3. How helpful do you find educational apps on your smartphone?
# a) Very helpful          114
# b) Somewhat helpful       73
# c) Neutral                33
# d) Not helpful at all     10
# Name: count, dtype: int64

# %%
df['3. How helpful do you find educational apps on your smartphone?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['4. Do you use smartphone apps to enhance your productivity in studies?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['5. How often do you use your smartphone to collaborate with classmates or peers for educational purposes?'].value_counts()
# Out:
# 5. How often do you use your smartphone to collaborate with classmates or peers for educational purposes?
# b) Several times a week    93
# a) Daily                   78
# c) Once a week             43
# d) Rarely or never         16
# Name: count, dtype: int64

# %%
df['5. How often do you use your smartphone to collaborate with classmates or peers for educational purposes?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['6. Which smartphone feature do you find most useful for educational purposes?'].value_counts()
# Out:
# 6. Which smartphone feature do you find most useful for educational purposes?
# a) Internet access for research                                       123
# b) Note-taking apps                                                    60
# c) Voice recording for lectures                                        32
# d) Camera for scanning documents or taking pictures of whiteboards     14
# Name: count, dtype: int64

# %%
df['6. Which smartphone feature do you find most useful for educational purposes?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['7. How often do you use your smartphone to access online educational platforms (e.g., Khan Academy, Coursera)?'].value_counts()
# Out:
# 7. How often do you use your smartphone to access online educational platforms (e.g., Khan Academy, Coursera)?
# a) Daily                   87
# b) Several times a week    87
# c) Once a week             36
# d) Rarely or never         19
# Name: count, dtype: int64

# %%
df['7. How often do you use your smartphone to access online educational platforms (e.g., Khan Academy, Coursera)?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['8. Have smartphones made it easier for you to access educational resources compared to traditional methods (e.g., books, libraries)?'].value_counts()
# Out:
# 8. Have smartphones made it easier for you to access educational resources compared to traditional methods (e.g., books, libraries)?
# a) Yes, significantly                        112
# b) Yes, to some extent                        78
# c) No, there is no significant difference     29
# d) No, it's more challenging                   9
# Name: count, dtype: int64

# %%
df['8. Have smartphones made it easier for you to access educational resources compared to traditional methods (e.g., books, libraries)?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['9. Do you use your smartphone to create and share educational content with others (e.g., videos, presentations)?'].value_counts()
# Out:
# 9. Do you use your smartphone to create and share educational content with others (e.g., videos, presentations)?
# a) Yes, regularly    107
# b) Occasionally       95
# c) Rarely             20
# d) Not at all          8
# Name: count, dtype: int64

# %%
df['9. Do you use your smartphone to create and share educational content with others (e.g., videos, presentations)?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['10. How often do you use your smartphone to participate in online educational forums or communities?'].value_counts()
# Out:
# 10. How often do you use your smartphone to participate in online educational forums or communities?
# b) Several times a week    101
# a) Daily                    67
# c) Once a week              44
# d) Rarely or never          18
# Name: count, dtype: int64

# %%
df['10. How often do you use your smartphone to participate in online educational forums or communities?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
